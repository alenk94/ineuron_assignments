# %% [markdown]
# # Import Libraries

# %%
import sqlite3 
import pandas as pd
from sklearn.tree import DecisionTreeRegressor 
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error 
from math import sqrt

# %% [markdown]
# # Read Data from the Database into pandas

# %%
# Create your connection.
cnx = sqlite3.connect('database.sqlite')
df_1 = pd.read_sql_query("SELECT * FROM Player_Attributes", cnx)

# %%
df_1.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0  ...    54.0       48.0     65.0             69.0            69.0
# 1  ...    54.0       48.0     65.0             69.0            69.0
# 2  ...    54.0       48.0     65.0             66.0            69.0
# 3  ...    53.0       47.0     62.0             63.0            66.0
# 4  ...    53.0       47.0     62.0             63.0            66.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
# 2        6.0         11.0        10.0             8.0          8.0
# 3        5.0         10.0         9.0             7.0          7.0
# 4        5.0         10.0         9.0             7.0          7.0
#
# [5 rows x 42 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   183978 non-null  int64
#  1   player_fifa_api_id   183978 non-null  int64
#  2   player_api_id        183978 non-null  int64
#  3   date                 183978 non-null  object
#  4   overall_rating       183142 non-null  float64
#  5   potential            183142 non-null  float64
#  6   preferred_foot       183142 non-null  object
#  7   attacking_work_rate  180748 non-null  object
#  8   defensive_work_rate  183142 non-null  object
#  9   crossing             183142 non-null  float64
#  10  finishing            183142 non-null  float64
#  11  heading_accuracy     183142 non-null  float64
#  12  short_passing        183142 non-null  float64
#  13  volleys              181265 non-null  float64
#  14  dribbling            183142 non-null  float64
#  15  curve                181265 non-null  float64
#  16  free_kick_accuracy   183142 non-null  float64
#  17  long_passing         183142 non-null  float64
#  18  ball_control         183142 non-null  float64
#  19  acceleration         183142 non-null  float64
#  20  sprint_speed         183142 non-null  float64
#  21  agility              181265 non-null  float64
#  22  reactions            183142 non-null  float64
#  23  balance              181265 non-null  float64
#  24  shot_power           183142 non-null  float64
#  25  jumping              181265 non-null  float64
#  26  stamina              183142 non-null  float64
#  27  strength             183142 non-null  float64
#  28  long_shots           183142 non-null  float64
#  29  aggression           183142 non-null  float64
#  30  interceptions        183142 non-null  float64
#  31  positioning          183142 non-null  float64
#  32  vision               181265 non-null  float64
#  33  penalties            183142 non-null  float64
#  34  marking              183142 non-null  float64
#  35  standing_tackle      183142 non-null  float64
#  36  sliding_tackle       181265 non-null  float64
#  37  gk_diving            183142 non-null  float64
#  38  gk_handling          183142 non-null  float64
#  39  gk_kicking           183142 non-null  float64
#  40  gk_positioning       183142 non-null  float64
#  41  gk_reflexes          183142 non-null  float64
# dtypes: float64(35), int64(3), object(4)
# memory usage: 59.0+ MB

# %%
df=df_1.dropna()

# %%
df=df.drop(['id','player_fifa_api_id','player_api_id','date'], axis=1)

# %%
df.shape
# Out:
# (180354, 38)

# %%
df.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0     44.0  ...    54.0       48.0     65.0             69.0            69.0
# 1     44.0  ...    54.0       48.0     65.0             69.0            69.0
# 2     44.0  ...    54.0       48.0     65.0             66.0            69.0
# 3     43.0  ...    53.0       47.0     62.0             63.0            66.0
# 4     43.0  ...    53.0       47.0     62.0             63.0            66.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
# 2        6.0         11.0        10.0             8.0          8.0
# 3        5.0         10.0         9.0             7.0          7.0
# 4        5.0         10.0         9.0             7.0          7.0
#
# [5 rows x 38 columns]

# %%
df['preferred_foot'].value_counts()
# Out:
# right    136247
# left      44107
# Name: preferred_foot, dtype: int64

# %%
df['attacking_work_rate'].value_counts()
# Out:
# medium    125070
# high       42823
# low         8569
# None        3317
# norm         317
# y             94
# stoc          86
# le            78
# Name: attacking_work_rate, dtype: int64

# %%
df=df[(df['attacking_work_rate']!= 'norm') & (df['attacking_work_rate']!= 'y') & (df['attacking_work_rate']!= 'stoc') & (df['attacking_work_rate']!= 'le')]

# %%
df['attacking_work_rate'].value_counts()
# Out:
# medium    125070
# high       42823
# low         8569
# None        3317
# Name: attacking_work_rate, dtype: int64

# %%
df.shape
# Out:
# (179779, 38)

# %%
df['defensive_work_rate'].value_counts()
# Out:
# medium    130846
# high       27041
# low        18432
# o           1328
# 1            421
# 2            334
# 3            243
# 5            231
# 7            207
# 0            188
# 6            179
# 9            143
# 4            116
# 8             70
# Name: defensive_work_rate, dtype: int64

# %%
df=df[(df['defensive_work_rate']=='medium') | (df['defensive_work_rate']=='high') | (df['defensive_work_rate']=='low')]

# %%
df.shape
# Out:
# (176319, 38)

# %%
preferred_foot = pd.get_dummies(df['preferred_foot'], drop_first=True)
attacking_work_rate=pd.get_dummies(df['attacking_work_rate'], drop_first=True)
defensive_work_rate=pd.get_dummies(df['defensive_work_rate'], drop_first=True)

# %%
df=pd.concat([df, preferred_foot, attacking_work_rate, defensive_work_rate], axis=1)

# %%
df.head()
# Out:
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0            67.0       71.0          right              medium
# 1            67.0       71.0          right              medium
# 2            62.0       66.0          right              medium
# 3            61.0       65.0          right              medium
# 4            61.0       65.0          right              medium
#
#   defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0              medium      49.0       44.0              71.0           61.0
# 1              medium      49.0       44.0              71.0           61.0
# 2              medium      49.0       44.0              71.0           61.0
# 3              medium      48.0       43.0              70.0           60.0
# 4              medium      48.0       43.0              70.0           60.0
#
#    volleys  ...  gk_handling  gk_kicking  gk_positioning  gk_reflexes  right  \
# 0     44.0  ...         11.0        10.0             8.0          8.0      1
# 1     44.0  ...         11.0        10.0             8.0          8.0      1
# 2     44.0  ...         11.0        10.0             8.0          8.0      1
# 3     43.0  ...         10.0         9.0             7.0          7.0      1
# 4     43.0  ...         10.0         9.0             7.0          7.0      1
#
#    high  low  medium  low  medium
# 0     0    0       1    0       1
# 1     0    0       1    0       1
# 2     0    0       1    0       1
# 3     0    0       1    0       1
# 4     0    0       1    0       1
#
# [5 rows x 44 columns]

# %%
df.drop(['preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    overall_rating  potential  crossing  finishing  heading_accuracy  \
# 0            67.0       71.0      49.0       44.0              71.0
# 1            67.0       71.0      49.0       44.0              71.0
# 2            62.0       66.0      49.0       44.0              71.0
# 3            61.0       65.0      48.0       43.0              70.0
# 4            61.0       65.0      48.0       43.0              70.0
#
#    short_passing  volleys  dribbling  curve  free_kick_accuracy  ...  \
# 0           61.0     44.0       51.0   45.0                39.0  ...
# 1           61.0     44.0       51.0   45.0                39.0  ...
# 2           61.0     44.0       51.0   45.0                39.0  ...
# 3           60.0     43.0       50.0   44.0                38.0  ...
# 4           60.0     43.0       50.0   44.0                38.0  ...
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes  right  high  low  \
# 0         11.0        10.0             8.0          8.0      1     0    0
# 1         11.0        10.0             8.0          8.0      1     0    0
# 2         11.0        10.0             8.0          8.0      1     0    0
# 3         10.0         9.0             7.0          7.0      1     0    0
# 4         10.0         9.0             7.0          7.0      1     0    0
#
#    medium  low  medium
# 0       1    0       1
# 1       1    0       1
# 2       1    0       1
# 3       1    0       1
# 4       1    0       1
#
# [5 rows x 41 columns]

# %%
y=df['overall_rating']
features=df.drop(['overall_rating'], axis=1)

# %%
from sklearn import preprocessing

# %%
min_max_scaler=preprocessing.MinMaxScaler()

# %%
scaled_features=min_max_scaler.fit_transform(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(.95)
pca.fit(scaled_features)
# Out:
# PCA(n_components=0.95)

# %%
features_1=pca.transform(scaled_features)

# %%
features_1.shape
# Out:
# (176319, 17)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features_1, y, test_size=0.25, random_state=100)

# %%
from xgboost import XGBRegressor
XGB=XGBRegressor()

# %%
XGB.fit(X_train,y_train)
# Out:
# [23:17:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor()

# %%
y_pred_train = XGB.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_train, y_pred_train)
score
# Out:
# 0.8705664578945638

# %%
y_pred_test = XGB.predict(X_test)
score=r2_score(y_test, y_pred_test)
score
# Out:
# 0.8661186919869349

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
   
    ' learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimators':[10,50,100,200]
    
}

# %%
grid= GridSearchCV(XGBRegressor(),param_grid, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [23:20:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=-10.827, total=   2.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [23:20:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.1s remaining:    0.0s
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=-11.007, total=   2.2s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [23:21:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.3s remaining:    0.0s
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=-11.049, total=   2.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [23:21:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=-10.878, total=   2.2s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [23:21:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=-11.007, total=   2.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [23:21:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.803, total=  10.3s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [23:21:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.799, total=   9.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [23:21:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.796, total=   9.3s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [23:21:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.803, total=   9.2s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [23:21:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.794, total=   9.2s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [23:21:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.868, total=  18.8s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [23:22:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.868, total=  21.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [23:22:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.866, total=  19.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [23:22:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.873, total=  19.2s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [23:23:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.866, total=  19.5s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [23:23:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.907, total=  37.9s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [23:24:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.906, total=  36.7s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [23:24:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.906, total=  40.8s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [23:25:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.910, total=  36.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [23:26:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.906, total=  37.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [23:26:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=-10.705, total=   3.3s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [23:26:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=-10.888, total=   3.5s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [23:26:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=-10.920, total=   3.2s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [23:26:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=-10.748, total=   3.3s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [23:26:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=-10.881, total=   3.6s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [23:26:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.885, total=  20.5s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [23:27:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.884, total=  18.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [23:27:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.884, total=  14.9s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [23:27:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.890, total=  14.9s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [23:28:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.884, total=  14.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [23:28:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.923, total=  29.7s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [23:28:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.923, total=  30.5s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [23:29:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.923, total=  31.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [23:29:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.925, total=  35.2s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [23:30:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.923, total=  32.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [23:31:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.943, total= 1.0min
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [23:32:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.944, total= 1.0min
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [23:33:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.944, total= 1.0min
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [23:34:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.945, total= 1.0min
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [23:35:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.944, total= 1.0min
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [23:36:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=-10.631, total=   5.7s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [23:36:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=-10.801, total=   5.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [23:36:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=-10.826, total=   5.7s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [23:36:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=-10.670, total=   5.8s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [23:36:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=-10.786, total=   5.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [23:36:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.952, total=  31.8s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [23:37:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.952, total=  30.8s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [23:37:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.952, total=  30.4s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [23:38:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.953, total=  30.9s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [23:38:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.952, total=  30.6s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [23:39:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [23:40:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [23:41:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [23:42:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.966, total= 1.1min
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [23:43:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.965, total= 1.2min
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [23:44:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.969, total= 2.2min
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [23:46:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.970, total= 2.1min
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [23:49:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.970, total= 2.3min
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [23:51:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.970, total= 2.2min
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [23:53:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.969, total= 2.2min
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [23:55:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=-10.626, total=   6.3s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [23:55:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=-10.798, total=   6.2s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [23:55:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=-10.824, total=   6.4s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [23:56:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=-10.666, total=   7.2s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [23:56:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=-10.781, total=   6.8s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [23:56:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.968, total=  55.8s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [23:57:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.969, total=  55.7s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [23:58:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.968, total=  57.4s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [23:59:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.969, total= 1.0min
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [00:00:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.967, total=  56.7s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [00:01:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.975, total= 2.3min
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [00:03:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.976, total= 2.3min
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [00:05:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.976, total= 2.1min
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [00:07:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.976, total= 2.2min
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [00:09:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.975, total= 2.2min
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [00:12:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.976, total= 4.5min
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [00:16:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.976, total= 4.5min
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [00:21:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.976, total= 4.5min
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [00:25:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.977, total= 4.6min
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [00:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.975, total= 4.5min
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [00:34:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=-10.827, total=   2.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [00:34:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=-11.007, total=   2.2s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [00:34:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=-11.049, total=   2.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [00:34:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=-10.878, total=   2.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [00:34:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=-11.007, total=   2.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [00:34:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.803, total=   9.4s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [00:35:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.799, total=   9.4s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [00:35:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.796, total=   9.4s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [00:35:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.803, total=  10.3s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [00:35:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.794, total=   9.6s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [00:35:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.868, total=  20.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [00:36:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.868, total=  20.2s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [00:36:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.866, total=  19.7s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [00:36:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.873, total=  19.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [00:37:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.866, total=  19.3s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [00:37:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.907, total=  38.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [00:37:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.906, total=  37.8s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [00:38:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.906, total=  37.8s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [00:39:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.910, total=  39.5s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [00:39:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.906, total=  39.4s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [00:40:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=-10.705, total=   3.8s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [00:40:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=-10.888, total=   3.7s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [00:40:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=-10.920, total=   3.4s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [00:40:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=-10.748, total=   3.4s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [00:40:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=-10.881, total=   3.3s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [00:40:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.885, total=  15.5s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [00:41:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.884, total=  14.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [00:41:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.884, total=  15.8s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [00:41:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.890, total=  15.9s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [00:41:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.884, total=  15.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [00:42:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.923, total=  31.5s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [00:42:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.923, total=  31.7s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [00:43:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.923, total=  31.3s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [00:43:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.925, total=  30.3s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [00:44:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.923, total=  30.6s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [00:44:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.943, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [00:45:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.944, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [00:46:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.944, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [00:47:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.945, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [00:49:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.944, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [00:50:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=-10.631, total=   5.9s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [00:50:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=-10.801, total=   6.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [00:50:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=-10.826, total=   6.3s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [00:50:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=-10.670, total=   5.8s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [00:50:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=-10.786, total=   6.2s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [00:50:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.952, total=  33.8s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [00:51:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.952, total=  32.3s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [00:51:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.952, total=  32.3s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [00:52:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.953, total=  31.9s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [00:52:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.952, total=  32.8s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [00:53:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [00:54:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [00:55:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [00:56:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.966, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [00:57:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [00:58:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.969, total= 2.4min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [01:01:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.970, total= 2.3min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [01:03:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.970, total= 2.3min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [01:05:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.970, total= 2.2min
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [01:07:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.969, total= 2.2min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [01:10:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=-10.626, total=   6.4s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [01:10:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=-10.798, total=   6.3s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [01:10:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=-10.824, total=   6.4s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [01:10:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=-10.666, total=   6.5s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [01:10:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=-10.781, total=   6.4s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [01:10:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.968, total=  55.3s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [01:11:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.969, total=  59.8s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [01:12:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.968, total=  56.3s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [01:13:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.969, total=  56.2s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [01:14:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.967, total=  56.6s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [01:15:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.975, total= 2.1min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [01:17:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.976, total= 2.1min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [01:19:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.976, total= 2.1min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [01:21:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.976, total= 2.1min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [01:23:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.975, total= 2.1min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [01:26:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.976, total= 4.4min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [01:30:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.976, total= 4.4min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [01:34:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.976, total= 4.5min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [01:39:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.977, total= 4.4min
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [01:43:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.975, total= 4.3min
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [01:47:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=-10.827, total=   2.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [01:48:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=-11.007, total=   2.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [01:48:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=-11.049, total=   2.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [01:48:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=-10.878, total=   2.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [01:48:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=-11.007, total=   2.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [01:48:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.803, total=  11.8s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [01:48:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.799, total=   9.6s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [01:48:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.796, total=  11.2s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [01:48:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.803, total=  11.3s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [01:48:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.794, total=  11.1s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [01:49:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.868, total=  20.5s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [01:49:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.868, total=  22.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [01:49:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.866, total=  24.5s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [01:50:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.873, total=  24.4s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [01:50:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.866, total=  27.6s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200 ...............
# [01:51:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=200, score=0.907, total= 1.0min
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200 ...............
# ...
# [02:17:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=-10.801, total=  12.8s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [02:17:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=-10.826, total=  12.9s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [02:18:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=-10.670, total=  12.9s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [02:18:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=-10.786, total=  12.8s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [02:18:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.952, total= 1.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [02:19:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.952, total= 1.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [02:20:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.952, total= 1.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [02:22:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.953, total= 1.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [02:23:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.952, total= 1.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [02:24:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.965, total=396.5min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [09:00:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [09:01:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [09:03:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.966, total= 1.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [09:04:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.965, total= 1.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [09:05:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.969, total= 2.2min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [09:07:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.970, total= 2.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [09:09:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.970, total= 2.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [09:11:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.970, total= 2.1min
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [09:13:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.969, total= 2.1min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [09:15:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=-10.626, total=   6.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [09:15:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=-10.798, total=   6.0s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [09:16:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=-10.824, total=   6.2s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [09:16:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=-10.666, total=   6.2s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [09:16:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=-10.781, total=   6.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [09:16:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.968, total=  54.0s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [09:17:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.969, total=  53.5s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [09:18:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.968, total=  54.5s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [09:19:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.969, total=  53.9s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [09:19:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.967, total=  54.5s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [09:20:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.975, total= 2.2min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [09:23:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.976, total= 2.2min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [09:25:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.976, total= 2.2min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [09:27:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.976, total= 2.1min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [09:29:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.975, total= 2.2min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [09:31:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.976, total= 4.3min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [09:35:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.976, total= 4.4min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [09:40:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.976, total= 4.6min
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [09:44:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-3949096c802a> in <module>
# ----> 1 grid.fit(X_train, y_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# ~/anaconda3/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~/anaconda3/lib/python3.7/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~/anaconda3/lib/python3.7/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
grid.best_params_

# %%
new_model=XGBRegressor(learning_rate= 1, max_depth= 5, n_estimators= 50)
new_model.fit(X_train, y_train)

# %%
y_pred_train = new_model.predict(X_train)
score=r2_score(y_train, y_pred_train)
score

# %%
y_pred_test = new_model.predict(X_test)
score=r2_score(y_test, y_pred_test)
score
