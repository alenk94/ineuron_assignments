# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('data_stocks.csv')
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
# ...

# %%
data.shape
# Out:
# (41266, 502)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
data_1=data.drop(['DATE','SP500'], axis=1)

# %%
data_1.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0     42.3300     143.6800     129.6300      82.040    102.2300      85.2200
# 1     42.3600     143.7000     130.3200      82.080    102.1400      85.6500
# 2     42.3100     143.6901     130.2250      82.030    102.2125      85.5100
# 3     42.3700     143.6400     130.0729      82.000    102.1400      85.4872
# 4     42.5378     143.6600     129.8800      82.035    102.0600      85.7001
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  ...  NYSE.WYN  NYSE.XEC  \
# 0       59.760       121.52        38.99       14.61  ...    84.370   119.035
# 1       59.840       121.48        39.01       14.71  ...    84.370   119.035
# 2       59.795       121.93        38.91       14.64  ...    84.585   119.260
# 3       59.620       121.44        38.84       14.63  ...    84.460   119.260
# 4       59.620       121.60        38.93       14.67  ...    84.470   119.610
#
# ...

# %% [markdown]
# ### Problem 1

# %% [markdown]
# There are various stocks for which we have collected a data set, which all stocks are apparently similar in performance

# %%
correlation=data_1.corr()

# %%
correlation.index
# Out:
# Index(['NASDAQ.AAL', 'NASDAQ.AAPL', 'NASDAQ.ADBE', 'NASDAQ.ADI', 'NASDAQ.ADP',
#        'NASDAQ.ADSK', 'NASDAQ.AKAM', 'NASDAQ.ALXN', 'NASDAQ.AMAT',
#        'NASDAQ.AMD',
#        ...
#        'NYSE.WYN', 'NYSE.XEC', 'NYSE.XEL', 'NYSE.XL', 'NYSE.XOM', 'NYSE.XRX',
#        'NYSE.XYL', 'NYSE.YUM', 'NYSE.ZBH', 'NYSE.ZTS'],
#       dtype='object', length=500)

# %%
correlation_df=pd.DataFrame(data=correlation.values, columns=correlation.index, index=correlation.index)

# %%
correlation_df.head()
# Out:
#              NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  \
# NASDAQ.AAL     1.000000     0.082065     0.542213    0.209446    0.245801
# NASDAQ.AAPL    0.082065     1.000000     0.714578    0.264269    0.265641
# NASDAQ.ADBE    0.542213     0.714578     1.000000    0.259282    0.476496
# NASDAQ.ADI     0.209446     0.264269     0.259282    1.000000   -0.085074
# NASDAQ.ADP     0.245801     0.265641     0.476496   -0.085074    1.000000
#
#              NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  \
# NASDAQ.AAL      0.610881    -0.441142     0.009581     0.681863    0.272518
# NASDAQ.AAPL     0.645233    -0.712522     0.326712     0.545541   -0.238091
# NASDAQ.ADBE     0.872353    -0.759604     0.488717     0.733609    0.201821
# NASDAQ.ADI      0.470756    -0.323603    -0.409747     0.504019    0.042083
# NASDAQ.ADP      0.325630    -0.229119     0.572143     0.099934    0.447506
#
# ...

# %%
correlation_df[correlation_df['NASDAQ.AAL'].values > 0.80].sort_values('NASDAQ.AAL', ascending=False)[:5]
# Out:
#             NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  \
# NASDAQ.AAL    1.000000     0.082065     0.542213    0.209446    0.245801
# NYSE.DAL      0.908578    -0.016610     0.452003    0.194325    0.012064
# NYSE.IVZ      0.859227     0.041431     0.617582    0.002995    0.332067
# NYSE.IT       0.853073     0.160422     0.736381    0.167713    0.457620
# NYSE.DE       0.850040     0.305125     0.677498    0.282661    0.463447
#
#             NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  \
# NASDAQ.AAL     0.610881    -0.441142     0.009581     0.681863    0.272518
# NYSE.DAL       0.537964    -0.444039    -0.056278     0.628435    0.170080
# NYSE.IVZ       0.555323    -0.386931     0.332546     0.587207    0.422932
# NYSE.IT        0.706307    -0.510452     0.308601     0.679780    0.424158
# NYSE.DE        0.787228    -0.649532     0.083421     0.710929    0.205290
#
# ...

# %% [markdown]
# ### Problem 2

# %% [markdown]
# How many Unique patterns that exist in the historical stock data set, based on fluctuations in price.

# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
data_2 = StandardScaler().fit_transform(data_1)
db = DBSCAN(eps=0.5, min_samples=30).fit(data_2)

# we are calculating these for showcasing in diagram
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)  # creating an array of true and false as the same size as db.labels
core_samples_mask[db.core_sample_indices_] = True  # setting the indices of the core regions to True
labels = db.labels_  # similar to the model.fit() method, it gives the labels of the clustered data

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0) # the label -1 is considered as noise by the DBSCAN algorithm
n_noise_ = list(labels).count(-1)  # calculating the number of clusters

# %%
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 6
# Estimated number of noise points: 40996

# %%
#elbow method
from sklearn.cluster import KMeans
wcss=[]
for i in range (1,20):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(data_2)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,20),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 15, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(data_2)
print(y_kmeans)
# Out:
# [11 11 11 ... 10 10 10]

# %% [markdown]
# ### Problem 3

# %% [markdown]
# Identify which all stocks are moving together and which all stocks are different from each other.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# convert data into numpy arrays
X = data_1.values

# Scaling the values
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

pca = PCA(n_components=150)
pca.fit(X_scaled)

# the amount of variance that each PCA explains
var = pca.explained_variance_ratio_

# cumulative varince explains
var1 = np.cumsum(np.round(var, decimals=4)*100)
print(var1)
# Out:
# [47.03 64.26 76.28 81.13 84.93 87.74 89.74 91.05 92.1  92.85 93.53 94.11
#  94.57 95.02 95.43 95.78 96.11 96.37 96.6  96.82 97.01 97.17 97.32 97.45
#  97.58 97.7  97.81 97.91 98.   98.08 98.16 98.24 98.31 98.38 98.44 98.5
#  98.56 98.61 98.66 98.71 98.75 98.79 98.83 98.87 98.91 98.94 98.97 99.
#  99.03 99.06 99.09 99.12 99.15 99.17 99.19 99.21 99.23 99.25 99.27 99.29
#  99.31 99.33 99.35 99.37 99.39 99.41 99.43 99.45 99.46 99.47 99.48 99.49
#  99.5  99.51 99.52 99.53 99.54 99.55 99.56 99.57 99.58 99.59 99.6  99.61
#  99.62 99.63 99.64 99.65 99.66 99.67 99.68 99.69 99.7  99.71 99.72 99.73
#  99.74 99.75 99.76 99.77 99.78 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79]

# %%
plt.plot(var1)

# %%
pca = PCA(n_components =20)
X1 = pca.fit_transform(X_scaled)
print(X1)
# Out:
# [[ 25.55018064  10.00580482  -9.38207446 ...  -0.72617905   1.87814923
#     2.56413649]
#  [ 25.64880185   9.89282687  -9.8023104  ...  -0.68954846   1.85209197
#     2.59117694]
#  [ 25.56345929   9.82533675  -9.67570287 ...  -0.79545134   1.7741566
#     2.64764419]
#  ...
#  [-22.76894921  13.32753802   6.56220278 ...   0.26908165  -1.46492069
#     1.67555218]
#  [-22.61319638  13.41831515   6.6755356  ...   0.25014081  -1.49675665
#     1.6846292 ]
#  [-22.72127837  13.36292841   6.60406294 ...   0.28638249  -1.48877358
#     1.63947052]]

# %%
print('Number of PCA :',len(pca.components_))
print(abs(pca.components_))
# Out:
# Number of PCA : 20
# [[0.03925756 0.04106421 0.0629084  ... 0.06247664 0.00253829 0.05169773]
#  [0.06428354 0.033861   0.00186129 ... 0.02040637 0.08122924 0.05950068]
#  [0.03985758 0.06416494 0.01207933 ... 0.02101011 0.06637293 0.02356977]
#  ...
#  [0.00598384 0.04778728 0.00105954 ... 0.01155209 0.01578379 0.01909476]
#  [0.01415985 0.02191725 0.01191272 ... 0.00298616 0.04737693 0.01423515]
#  [0.00547209 0.03347194 0.04152474 ... 0.02496868 0.03751941 0.00727515]]

# %%
comp = pd.DataFrame(pca.components_, columns = data_1.columns)
comp.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0   -0.039258    -0.041064    -0.062908   -0.009788   -0.035866    -0.054668
# 1   -0.064284     0.033861     0.001861   -0.032453    0.043511    -0.029519
# 2   -0.039858     0.064165     0.012079    0.043266   -0.037239     0.040506
# 3    0.007578     0.077164     0.008564   -0.027896   -0.017418     0.008973
# 4   -0.033303    -0.016981     0.002438   -0.038330   -0.102023    -0.034831
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  ...  NYSE.WYN  NYSE.XEC  \
# 0     0.050356    -0.035396    -0.044060   -0.014671  ... -0.049413  0.057001
# 1     0.016178     0.058286    -0.052667    0.012376  ... -0.058941  0.030277
# 2    -0.053892    -0.051099     0.030738   -0.086428  ... -0.003223  0.022125
# 3    -0.032239     0.034448     0.051511   -0.077594  ...  0.021692  0.060885
# 4    -0.011187     0.037595    -0.039683   -0.014357  ... -0.036672 -0.011451
#
# ...
